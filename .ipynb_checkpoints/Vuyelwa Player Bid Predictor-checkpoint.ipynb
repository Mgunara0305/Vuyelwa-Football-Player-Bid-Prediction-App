# %% [markdown]
# ## Import the Required Libraries

# %%
# For Data Analysis and exploration
import pandas as pd


# For numerical computations
import numpy as np


#for plotting and visualizations
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 2. Read the dataset

# %%
df = pd.read_csv('players-data.csv')

# %% [markdown]
# ## 3. Data Cleaning

# %% [markdown]
# ##  a. Understand the dataframe shape

# %%
df.shape
# Out:
# (18539, 58)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18539 entries, 0 to 18538
# Data columns (total 58 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   full name                    18539 non-null  object
#  1   overall_rating               18539 non-null  int64
#  2   value                        18539 non-null  int64
#  3   Positions Played             18539 non-null  object
#  4   best_position                18539 non-null  object
#  5   Nationality                  18539 non-null  object
#  6   Image Link                   18539 non-null  object
#  7   Age                          18539 non-null  int64
#  8   Height(in cm)                18539 non-null  int64
#  9   Weight(in kg)                18539 non-null  int64
#  10  Club Name                    18539 non-null  object
#  11  Wage                         18539 non-null  int64
#  12  Release Clause               18539 non-null  int64
#  13  Club Position                18539 non-null  object
#  14  Contract Until               18539 non-null  object
#  15  Club Jersey Number           18539 non-null  object
#  16  Joined On                    18539 non-null  int64
#  17  Preferred Foot               18539 non-null  object
#  18  skill_moves                  18539 non-null  int64
#  19  National Team Name           18539 non-null  object
#  20  National Team Position       18539 non-null  object
#  21  National Team Jersey Number  18539 non-null  object
#  22  attacking_work_rate          18539 non-null  object
#  23  defensive_work_rate          18539 non-null  object
#  24  pace                         18539 non-null  int64
#  25  shooting                     18539 non-null  int64
#  26  passing                      18539 non-null  int64
#  27  dribbling                    18539 non-null  int64
#  28  defending                    18539 non-null  int64
#  29  physicality                  18539 non-null  int64
#  30  crossing                     18539 non-null  int64
#  31  finishing                    18539 non-null  int64
#  32  heading_accuracy             18539 non-null  int64
#  33  Curve                        18539 non-null  int64
#  34  freekick_accuracy            18539 non-null  int64
#  35  ballcontrol                  18539 non-null  int64
#  36  acceleration                 18539 non-null  int64
#  37  sprint_speed                 18539 non-null  int64
#  38  agility                      18539 non-null  int64
#  39  reactions                    18539 non-null  int64
#  40  balance                      18539 non-null  int64
#  41  shot_power                   18539 non-null  int64
#  42  jumping                      18539 non-null  int64
#  43  stamina                      18539 non-null  int64
#  44  strength                     18539 non-null  int64
#  45  aggression                   18539 non-null  int64
#  46  interceptions                18539 non-null  int64
#  47  positioning                  18539 non-null  int64
#  48  vision                       18539 non-null  int64
#  49  penalties                    18539 non-null  int64
#  50  composure                    18539 non-null  int64
#  51  marking                      18539 non-null  int64
#  52  standing_tackle              18539 non-null  int64
#  53  sliding_tackle               18539 non-null  int64
#  54  goalkeeper_diving            18539 non-null  int64
#  55  goalkeeper_handling          18539 non-null  int64
#  56   goalkeeperkicking           18539 non-null  int64
#  57  Goalkeeper Reflexes          18539 non-null  int64
# dtypes: int64(43), object(15)
# memory usage: 8.2+ MB

# %%
df.columns
# Out:
# Index(['full name', 'overall_rating', 'value', 'Positions Played',
#        'best_position', 'Nationality', 'Image Link', 'Age', 'Height(in cm)',
#        'Weight(in kg)', 'Club Name', 'Wage', 'Release Clause', 'Club Position',
#        'Contract Until', 'Club Jersey Number', 'Joined On', 'Preferred Foot',
#        'skill_moves', 'National Team Name', 'National Team Position',
#        'National Team Jersey Number', 'attacking_work_rate',
#        'defensive_work_rate', 'pace', 'shooting', 'passing', 'dribbling',
#        'defending', 'physicality', 'crossing', 'finishing', 'heading_accuracy',
#        'Curve', 'freekick_accuracy', 'ballcontrol', 'acceleration',
#        'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power',
#        'jumping', 'stamina', 'strength', 'aggression', 'interceptions',
#        'positioning', 'vision', 'penalties', 'composure', 'marking',
#        'standing_tackle', 'sliding_tackle', 'goalkeeper_diving',
#        'goalkeeper_handling', ' goalkeeperkicking', 'Goalkeeper Reflexes'],
#       dtype='object')

# %%
df[0:5]
# Out:
#             full name  overall_rating      value Positions Played  \
# 0        Lionel Messi              91   54000000               RW
# 1       Karim Benzema              91   64000000            CF,ST
# 2  Robert Lewandowski              91   84000000               ST
# 3     Kevin De Bruyne              91  107500000           CM,CAM
# 4       Kylian Mbappé              91  190500000            ST,LW
#
#   best_position Nationality                                        Image Link  \
# 0           CAM   Argentina  https://cdn.sofifa.net/players/158/023/23_60.png
# 1            CF      France  https://cdn.sofifa.net/players/165/153/23_60.png
# 2            ST      Poland  https://cdn.sofifa.net/players/188/545/23_60.png
# 3            CM     Belgium  https://cdn.sofifa.net/players/192/985/23_60.png
# 4            ST      France  https://cdn.sofifa.net/players/231/747/23_60.png
#
#    Age  Height(in cm)  Weight(in kg)  ... vision  penalties  composure  \
# 0   35            169             67  ...     94         75         96
# 1   34            185             81  ...     89         84         90
# 2   33            185             81  ...     81         90         88
# 3   31            181             70  ...     94         83         89
# 4   23            182             73  ...     83         80         88
#
#   marking standing_tackle sliding_tackle  goalkeeper_diving  \
# 0      20              35             24                  6
# 1      43              24             18                 13
# 2      35              42             19                 15
# 3      68              65             53                 15
# 4      26              34             32                 13
#
#   goalkeeper_handling   goalkeeperkicking Goalkeeper Reflexes
# 0                  11                  15                   8
# 1                  11                   5                   7
# 2                   6                  12                  10
# 3                  13                   5                  13
# 4                   5                   7                   6
#
# [5 rows x 58 columns]

# %% [markdown]
# ## Since we are to predict using player attributes we shall first off drop all columns that to not pertain to player attributes but first off it is always good practice to create a backup of the original dataset.

# %%
backup=df.copy()

# %%
df.drop(columns=['full name','Nationality','Image Link','Height(in cm)','Weight(in kg)','Club Name','Wage','Release Clause','Club Position','Contract Until','Club Jersey Number','Joined On','Preferred Foot','National Team Name','National Team Position','National Team Jersey Number'],inplace=True)

# %%
df.shape
# Out:
# (18539, 42)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18539 entries, 0 to 18538
# Data columns (total 42 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   overall_rating       18539 non-null  int64
#  1   value                18539 non-null  int64
#  2   Positions Played     18539 non-null  object
#  3   best_position        18539 non-null  object
#  4   Age                  18539 non-null  int64
#  5   skill_moves          18539 non-null  int64
#  6   attacking_work_rate  18539 non-null  object
#  7   defensive_work_rate  18539 non-null  object
#  8   pace                 18539 non-null  int64
#  9   shooting             18539 non-null  int64
#  10  passing              18539 non-null  int64
#  11  dribbling            18539 non-null  int64
#  12  defending            18539 non-null  int64
#  13  physicality          18539 non-null  int64
#  14  crossing             18539 non-null  int64
#  15  finishing            18539 non-null  int64
#  16  heading_accuracy     18539 non-null  int64
#  17  Curve                18539 non-null  int64
#  18  freekick_accuracy    18539 non-null  int64
#  19  ballcontrol          18539 non-null  int64
#  20  acceleration         18539 non-null  int64
#  21  sprint_speed         18539 non-null  int64
#  22  agility              18539 non-null  int64
#  23  reactions            18539 non-null  int64
#  24  balance              18539 non-null  int64
#  25  shot_power           18539 non-null  int64
#  26  jumping              18539 non-null  int64
#  27  stamina              18539 non-null  int64
#  28  strength             18539 non-null  int64
#  29  aggression           18539 non-null  int64
#  30  interceptions        18539 non-null  int64
#  31  positioning          18539 non-null  int64
#  32  vision               18539 non-null  int64
#  33  penalties            18539 non-null  int64
#  34  composure            18539 non-null  int64
#  35  marking              18539 non-null  int64
#  36  standing_tackle      18539 non-null  int64
#  37  sliding_tackle       18539 non-null  int64
#  38  goalkeeper_diving    18539 non-null  int64
#  39  goalkeeper_handling  18539 non-null  int64
#  40   goalkeeperkicking   18539 non-null  int64
#  41  Goalkeeper Reflexes  18539 non-null  int64
# dtypes: int64(38), object(4)
# memory usage: 5.9+ MB

# %%
df['value']=df['value'].astype(float)

# %% [markdown]
# ## checking for missing values

# %%
df.isna().sum()
# Out:
# overall_rating         0
# value                  0
# Positions Played       0
# best_position          0
# Age                    0
# skill_moves            0
# attacking_work_rate    0
# defensive_work_rate    0
# pace                   0
# shooting               0
# passing                0
# dribbling              0
# defending              0
# physicality            0
# crossing               0
# finishing              0
# heading_accuracy       0
# Curve                  0
# freekick_accuracy      0
# ballcontrol            0
# acceleration           0
# sprint_speed           0
# agility                0
# reactions              0
# balance                0
# shot_power             0
# jumping                0
# stamina                0
# strength               0
# aggression             0
# interceptions          0
# positioning            0
# vision                 0
# penalties              0
# composure              0
# marking                0
# standing_tackle        0
# sliding_tackle         0
# goalkeeper_diving      0
# goalkeeper_handling    0
#  goalkeeperkicking     0
# Goalkeeper Reflexes    0
# dtype: int64

# %% [markdown]
# ## Check for Duplicated Values

# %%
df.duplicated().sum()
# Out:
# 119

# %%
df = df.drop_duplicates()

# %% [markdown]
# ## Check for null values

# %%
df.isnull().sum()
# Out:
# overall_rating         0
# value                  0
# Positions Played       0
# best_position          0
# Age                    0
# skill_moves            0
# attacking_work_rate    0
# defensive_work_rate    0
# pace                   0
# shooting               0
# passing                0
# dribbling              0
# defending              0
# physicality            0
# crossing               0
# finishing              0
# heading_accuracy       0
# Curve                  0
# freekick_accuracy      0
# ballcontrol            0
# acceleration           0
# sprint_speed           0
# agility                0
# reactions              0
# balance                0
# shot_power             0
# jumping                0
# stamina                0
# strength               0
# aggression             0
# interceptions          0
# positioning            0
# vision                 0
# penalties              0
# composure              0
# marking                0
# standing_tackle        0
# sliding_tackle         0
# goalkeeper_diving      0
# goalkeeper_handling    0
#  goalkeeperkicking     0
# Goalkeeper Reflexes    0
# dtype: int64

# %%
# Rename the column
df.rename(columns={'best_position': 'position'}, inplace=True)
df.rename(columns={'attacking_work_rate': 'attacking_workrate'}, inplace=True)
df.rename(columns={'defensive_work_rate': 'defensive_workrate'}, inplace=True)

# %%
df.to_csv('Cleaned df.csv')

# %% [markdown]
# ## 4.ENTROPY DATA ANALYSIS

# %%
sns.displot(df['value'])

# %%
df['overall_rating'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.barplot(x=df['overall_rating'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(20, 10))  # Adjust the width and height as needed

# Create the distribution plot
sns.displot(data=df, x='Positions Played', kind='hist')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=90)  # Adjust the rotation angle as needed

# Show the plot
plt.show()

# %%
df.drop(columns=['Positions Played'],inplace=True)

# %%
sns.barplot(x=df['position'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['Age'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['skill_moves'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['attacking_workrate'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['defensive_workrate'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['pace'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['shooting'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['passing'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['dribbling'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['defending'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['physicality'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['crossing'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['finishing'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['heading_accuracy'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.displot(df['Curve'])

# %%
sns.barplot(x=df['Curve'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['freekick_accuracy'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['ballcontrol'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['acceleration'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['sprint_speed'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['agility'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['reactions'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['balance'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['shot_power'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['jumping'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['stamina'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['strength'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['aggression'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['interceptions'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['positioning'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['vision'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['penalties'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['composure'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['marking'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['standing_tackle'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['sliding_tackle'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['goalkeeper_diving'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['goalkeeper_handling'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df[' goalkeeperkicking'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(x=df['Goalkeeper Reflexes'],y=df['value'])
plt.xticks(rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.rename(columns={'Goalkeeper Reflexes': 'goalkeeper_reflexes'}, inplace=True)

# %%
df.corr()['value']
# Out:
# C:\Users\vuYELwa thE\AppData\Local\Temp\ipykernel_9124\1634987583.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['value']
# overall_rating         0.560209
# value                  1.000000
# Age                    0.032708
# skill_moves            0.247329
# pace                   0.203616
# shooting               0.274568
# passing                0.398550
# dribbling              0.404820
# defending              0.162189
# physicality            0.234025
# crossing               0.228569
# finishing              0.214991
# heading_accuracy       0.166785
# Curve                  0.252148
# freekick_accuracy      0.210030
# ballcontrol            0.271880
# acceleration           0.157738
# sprint_speed           0.164959
# agility                0.169462
# reactions              0.496979
# balance                0.119911
# shot_power             0.302128
# jumping                0.111304
# stamina                0.196196
# strength               0.129289
# aggression             0.186210
# interceptions          0.144351
# positioning            0.219458
# vision                 0.328143
# penalties              0.189401
# composure              0.389631
# marking                0.144289
# standing_tackle        0.129888
# sliding_tackle         0.111382
# goalkeeper_diving     -0.025908
# goalkeeper_handling   -0.025441
#  goalkeeperkicking    -0.023677
# goalkeeper_reflexes   -0.022636
# Name: value, dtype: float64

# %%
def sort_correlations(df):
    # Calculate the correlation matrix
    corr_matrix = df.corr()

    # Sort correlations in descending order
    sorted_correlations = corr_matrix['value'].sort_values(ascending=False)

    return sorted_correlations

# Call the function with your DataFrame
sorted_correlations = sort_correlations(df)

# Print the sorted correlations
print(sorted_correlations)
# Out:
# C:\Users\vuYELwa thE\AppData\Local\Temp\ipykernel_9124\1400491896.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
# value                  1.000000
# overall_rating         0.560209
# reactions              0.496979
# dribbling              0.404820
# passing                0.398550
# composure              0.389631
# vision                 0.328143
# shot_power             0.302128
# shooting               0.274568
# ballcontrol            0.271880
# Curve                  0.252148
# skill_moves            0.247329
# physicality            0.234025
# crossing               0.228569
# positioning            0.219458
# finishing              0.214991
# freekick_accuracy      0.210030
# pace                   0.203616
# stamina                0.196196
# penalties              0.189401
# aggression             0.186210
# agility                0.169462
# heading_accuracy       0.166785
# sprint_speed           0.164959
# defending              0.162189
# acceleration           0.157738
# interceptions          0.144351
# marking                0.144289
# standing_tackle        0.129888
# strength               0.129289
# balance                0.119911
# sliding_tackle         0.111382
# jumping                0.111304
# Age                    0.032708
# goalkeeper_reflexes   -0.022636
#  goalkeeperkicking    -0.023677
# goalkeeper_handling   -0.025441
# goalkeeper_diving     -0.025908
# Name: value, dtype: float64

# %% [markdown]
# ## For the sake of System Accuracy, we are going to select the top 20 attribute columns that have high corelation with player and use the for training and testing. Hemce we drop all the columns that have less correlation with value.

# %%
# Drop specified columns

df.drop(columns=['penalties', 'heading_accuracy', 'acceleration', 'standing_tackle', 
'strength', 'sliding_tackle', 'jumping', 'Age', 'goalkeeper_reflexes', 
' goalkeeperkicking', 'goalkeeper_handling', 'goalkeeper_diving'], inplace=True)

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\vuYELwa thE\AppData\Local\Temp\ipykernel_9124\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18420 entries, 0 to 18538
# Data columns (total 29 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   overall_rating      18420 non-null  int64
#  1   value               18420 non-null  float64
#  2   position            18420 non-null  object
#  3   skill_moves         18420 non-null  int64
#  4   attacking_workrate  18420 non-null  object
#  5   defensive_workrate  18420 non-null  object
#  6   pace                18420 non-null  int64
#  7   shooting            18420 non-null  int64
#  8   passing             18420 non-null  int64
#  9   dribbling           18420 non-null  int64
#  10  defending           18420 non-null  int64
#  11  physicality         18420 non-null  int64
#  12  crossing            18420 non-null  int64
#  13  finishing           18420 non-null  int64
#  14  Curve               18420 non-null  int64
#  15  freekick_accuracy   18420 non-null  int64
#  16  ballcontrol         18420 non-null  int64
#  17  sprint_speed        18420 non-null  int64
#  18  agility             18420 non-null  int64
#  19  reactions           18420 non-null  int64
#  20  balance             18420 non-null  int64
#  21  shot_power          18420 non-null  int64
#  22  stamina             18420 non-null  int64
#  23  aggression          18420 non-null  int64
#  24  interceptions       18420 non-null  int64
#  25  positioning         18420 non-null  int64
#  26  vision              18420 non-null  int64
#  27  composure           18420 non-null  int64
#  28  marking             18420 non-null  int64
# dtypes: float64(1), int64(25), object(3)
# memory usage: 4.7+ MB

# %%
df.to_csv('Cleaned df.csv')

# %% [markdown]
# ## 5.Model Training, Testing and Evaluation

# %%
X = df.drop(columns=['value'])
y = df['value']

# %%
X
# Out:
#        overall_rating position  skill_moves attacking_workrate  \
# 0                  91      CAM            4                Low
# 1                  91       CF            4             Medium
# 2                  91       ST            4               High
# 3                  91       CM            4               High
# 4                  91       ST            5               High
# ...               ...      ...          ...                ...
# 18534              47      CAM            2             Medium
# 18535              47      CDM            2             Medium
# 18536              47       RM            2               High
# 18537              47       CB            2             Medium
# 18538              47       LB            2             Medium
#
#       defensive_workrate  pace  shooting  passing  dribbling  defending  ...  \
# 0                    Low    81        89       90         94         34  ...
# 1                 Medium    80        88       83         87         39  ...
# 2                 Medium    75        91       79         86         44  ...
# 3                   High    74        88       93         87         64  ...
# 4                    Low    97        89       80         92         36  ...
# ...                  ...   ...       ...      ...        ...        ...  ...
# 18534             Medium    68        48       43         51         31  ...
# 18535             Medium    55        37       41         47         48  ...
# 18536             Medium    64        40       49         52         37  ...
# 18537             Medium    52        24       25         32         52  ...
# 18538             Medium    61        29       35         46         44  ...
#
#        reactions  balance  shot_power  stamina  aggression  interceptions  \
# 0             92       95          86       70          44             40
# 1             92       72          87       82          63             39
# 2             93       82          91       76          81             49
# 3             91       78          92       88          75             66
# 4             93       81          88       87          64             38
# ...          ...      ...         ...      ...         ...            ...
# 18534         44       63          50       32          37             22
# 18535         51       80          50       34          52             46
# 18536         49       73          54       36          39             24
# 18537         43       66          34       49          42             54
# 18538         45       76          29       56          47             40
#
#        positioning  vision  composure  marking
# 0               93      94         96       20
# 1               92      89         90       43
# 2               94      81         88       35
# 3               88      94         89       68
# 4               92      83         88       26
# ...            ...     ...        ...      ...
# 18534           50      52         47       39
# 18535           35      40         45       46
# 18536           42      50         59       39
# 18537           23      32         41       50
# 18538           36      39         32       47
#
# [18420 rows x 28 columns]

# %%
y
# Out:
# 0         54000000.0
# 1         64000000.0
# 2         84000000.0
# 3        107500000.0
# 4        190500000.0
#             ...
# 18534       110000.0
# 18535        90000.0
# 18536       130000.0
# 18537       100000.0
# 18538        60000.0
# Name: value, Length: 18420, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error,accuracy_score,mean_squared_error

# %%
ohe = OneHotEncoder()
ohe.fit(X[['position','attacking_workrate','defensive_workrate']])
# Out:
# OneHotEncoder()

# %%
column_trans = make_column_transformer((OneHotEncoder(),['position','attacking_workrate','defensive_workrate']),remainder='passthrough')

# %%
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %% [markdown]
# ## Linear Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[1,3,4])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.31189014207183596
# MAE 3257589.614077224
# C:\Users\vuYELwa thE\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# # KNN

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[1,3,4])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\vuYELwa thE\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.7518491291166448
# MAE 1240251.5385450597

# %% [markdown]
# ## Decision Tree Regressor

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[1,3,4])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\vuYELwa thE\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8190516907685066
# MAE 1055032.71985792

# %% [markdown]
# ## Random Forest

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[1,3,4])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# C:\Users\vuYELwa thE\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:972: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
# R2 score 0.8604632549058723
# MAE 909526.9520168724

# %% [markdown]
# ## Extra Trees Regressor

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [1,3,4])
], remainder='passthrough')

step2 = ExtraTreesRegressor(n_estimators=100,
                            random_state=3,
                            max_samples=None,
                            max_features=0.75,
                            max_depth=15)

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

pipe.fit(X_train, y_train)

y_pred = pipe.predict(X_test)

print('R2 score', r2_score(y_test, y_pred))
print('MAE', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score 0.8279096760155957
# MAE 933051.6416444287

# %% [markdown]
# ## Light GBM

# %%
import lightgbm as lgb

# Assuming X_train, X_test, y_train, and y_test are defined

# Convert categorical features into one-hot encoding
X_train_encoded = pd.get_dummies(X_train, drop_first=True)
X_test_encoded = pd.get_dummies(X_test, drop_first=True)

# Create a LightGBM dataset
train_data = lgb.Dataset(X_train_encoded, label=y_train)
test_data = lgb.Dataset(X_test_encoded, label=y_test)

# Set LightGBM parameters
params = {
    'objective': 'regression',
    'metric': 'mae',  # You can change the metric as needed
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}

# Train the model
num_round = 5000  # Number of boosting rounds
bst = lgb.train(params, train_data, num_round, valid_sets=[test_data])

# Make predictions
y_pred = bst.predict(X_test_encoded, num_iteration=bst.best_iteration)

# Evaluate the model
print('R2 score:', r2_score(y_test, y_pred))
print('MAE:', mean_absolute_error(y_test, y_pred))
# Out:
# R2 score: 0.8349145181153073
# MAE: 914409.5191499545

# %%
import pickle

# %%
pickle.dump(pipe,open('RandomForestRegressor.pkl','wb'))

# %%
import pickle

# Load the saved pipeline
with open('RandomForestRegressor.pkl', 'rb') as f:
    loaded_pipe = pickle.load(f)

# Define your data frame with the data you want to predict
# Replace df_predict with the name of your DataFrame and provide the data you want to predict
# Make sure the columns in df_predict match the columns used during training

# For example, if you have a DataFrame called df with the data you want to predict:
# Replace df with the name of your DataFrame
# Replace the values in the DataFrame with the data you want to predict
# Make sure the column names and order match the data that the pipeline was trained on

# Predict using the loaded pipeline
predictions = loaded_pipe.predict(df)

# Print the predictions
print(predictions)
# Out:
# [5.40000000e+07 7.72583333e+07 8.41308333e+07 ... 9.57033061e+04
#  1.00306258e+05 8.20570509e+04]
